# %%
import cv2
age_model = cv2.dnn.readNetFromCaffe("age.prototxt","dex_imdb_wiki.caffemodel")
gender_model= cv2.dnn.readNetFromCaffe("gender.prototxt","gender.caffemodel")

# %%
img1 = 'C:/Users/prash/OneDrive/Desktop/project/woman1.jpg'

# %%
# %run "age_gender_project_akash.ipynb"
# Out:
# women
# given input image of --> women who is--> (49.0, 'year_old')

# %%
img1 = 'C:/Users/prash/OneDrive/Desktop/project/woman3.jpg'

# %%
# %run "age_gender_project_akash.ipynb"
# Out:
# women
# given input image of --> women who is--> (28.0, 'year_old')

# %%
img1 = 'C:/Users/prash/OneDrive/Desktop/project/men.jpg'

# %%
# %run "age_gender_project_akash.ipynb"
# Out:
# men
# given input image of --> men who is--> (32.0, 'year_old')

# %%
img1 = 'C:/Users/prash/OneDrive/Desktop/project/men3.jpg'

# %%
# %run "age_gender_project_akash.ipynb"
# Out:
# men
# given input image of --> men who is--> (56.0, 'year_old')

# %%
img1 = 'C:/Users/prash/OneDrive/Desktop/project/men4.jpg'

# %%
# %run "age_gender_project_akash.ipynb"
# Out:
# men
# given input image of --> men who is--> (70.0, 'year_old')

# %%
img1 = 'C:/Users/prash/OneDrive/Desktop/project/child.jpg'

# %%
# %run "age_gender_project_akash.ipynb"
# Out:
# men
# given input image of --> men who is--> (15.0, 'year_old')
