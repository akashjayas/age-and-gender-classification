# %%
import cv2
age_model = cv2.dnn.readNetFromCaffe("age.prototxt","dex_imdb_wiki.caffemodel")
gender_model= cv2.dnn.readNetFromCaffe("gender.prototxt","gender.caffemodel")

# %% [markdown]
# ### Testing Image 1

# %%
input_img = 'C:/Users/prash/OneDrive/Desktop/project/images.jfif'

# %%
# %run "TRAINING.ipynb"
# Out:
#                      ( men , 28.0 )
# given input image of --> men who is--> 28.0 year_old

# %% [markdown]
# ### Testing Image 2

# %%
input_img = 'C:/Users/prash/OneDrive/Desktop/project/woman3.jpg'

# %%
# %run "TRAINING.ipynb"
# Out:
#                      ( women , 48.0 )
# given input image of --> women who is--> 48.0 year_old

# %% [markdown]
# ### Testing Image 3

# %%
input_img = 'C:/Users/prash/OneDrive/Desktop/project/woman1.jpg'

# %%
# %run "TRAINING.ipynb"
# Out:
#                      ( women , 28.0 )
# given input image of --> women who is--> 28.0 year_old

# %% [markdown]
# ### Testing Image 3

# %%
input_img = 'C:/Users/prash/OneDrive/Desktop/project/men.jpg'

# %%
# %run "TRAINING.ipynb"
# Out:
#                      ( men , 32.0 )
# given input image of --> men who is--> 32.0 year_old

# %% [markdown]
# ### Testing Image 4

# %%
input_img = 'C:/Users/prash/OneDrive/Desktop/project/men3.jpg'

# %%
# %run "TRAINING.ipynb"
# Out:
#                      ( men , 56.0 )
# given input image of --> men who is--> 56.0 year_old

# %% [markdown]
# ### Testing Image 5

# %%
input_img = 'C:/Users/prash/OneDrive/Desktop/project/men4.jpg'

# %%
# %run "TRAINING.ipynb"
# Out:
#                      ( men , 70.0 )
# given input image of --> men who is--> 70.0 year_old

# %% [markdown]
# ### Testing Image 6

# %%
input_img = 'C:/Users/prash/OneDrive/Desktop/project/child.jpg'

# %%
# %run "TRAINING.ipynb"
# Out:
#                      ( men , 15.0 )
# given input image of --> men who is--> 15.0 year_old
